# %%
import pandas as pd
import numpy as np 
from sklearn import linear_model
import seaborn as sns

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.arima.model import ARIMAResults
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.graphics.tsaplots import plot_predict
import math
import statsmodels.api as sm

# %%
import statsmodels.graphics.tsaplots as stat_graph

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold

# %%
import matplotlib.pyplot as plt

# %%
df_final = pd.read_csv('/Users/Daniyar/Data Science/ML_Course/MDS_ML_Project/Data/df_final.csv', index_col="time")

# %%
df_final.head()
# Out:
#                            generation biomass  \
# time
# 2014-12-31 23:00:00+00:00               447.0
# 2015-01-01 00:00:00+00:00               449.0
# 2015-01-01 01:00:00+00:00               448.0
# 2015-01-01 02:00:00+00:00               438.0
# 2015-01-01 03:00:00+00:00               428.0
#
#                            generation fossil brown coal/lignite  \
# time
# 2014-12-31 23:00:00+00:00                                 329.0
# 2015-01-01 00:00:00+00:00                                 328.0
# 2015-01-01 01:00:00+00:00                                 323.0
# 2015-01-01 02:00:00+00:00                                 254.0
# 2015-01-01 03:00:00+00:00                                 187.0
#
#                            generation fossil gas  generation fossil hard coal  \
# time
# 2014-12-31 23:00:00+00:00                 4844.0                       4821.0
# 2015-01-01 00:00:00+00:00                 5196.0                       4755.0
# ...

# %%
df_final.shape
# Out:
# (35064, 105)

# %%
print(df_final.columns.tolist())
# Out:
# ['generation biomass', 'generation fossil brown coal/lignite', 'generation fossil gas', 'generation fossil hard coal', 'generation fossil oil', 'generation hydro pumped storage consumption', 'generation hydro run-of-river and poundage', 'generation hydro water reservoir', 'generation nuclear', 'generation other', 'generation other renewable', 'generation solar', 'generation waste', 'generation wind onshore', 'forecast solar day ahead', 'forecast wind onshore day ahead', 'total load forecast', 'total load actual', 'price day ahead', 'price actual', 'temp_Barcelona', 'temp_min_Barcelona', 'temp_max_Barcelona', 'pressure_Barcelona', 'humidity_Barcelona', 'wind_speed_Barcelona', 'wind_deg_Barcelona', 'rain_1h_Barcelona', 'rain_3h_Barcelona', 'snow_3h_Barcelona', 'clouds_all_Barcelona', 'weather_broken clouds_Barcelona', 'weather_few clouds_Barcelona', 'weather_light rain_Barcelona', 'weather_others_Barcelona', 'weather_scattered clouds_Barcelona', 'weather_sky is clear_Barcelona', 'temp_
# ...

# %%
df_final['generation solar'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df_final['generation wind onshore'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df_final[['generation solar','generation wind onshore']].plot(subplots=True, layout=(2,1))
# Out:
# array([[<AxesSubplot:xlabel='time'>],
#        [<AxesSubplot:xlabel='time'>]], dtype=object)

# %%
values = df_final[['generation solar','generation wind onshore']]

# %%
solar = df_final['generation solar']

# %%
solar
# Out:
# time
# 2014-12-31 23:00:00+00:00    49.0
# 2015-01-01 00:00:00+00:00    50.0
# 2015-01-01 01:00:00+00:00    50.0
# 2015-01-01 02:00:00+00:00    50.0
# 2015-01-01 03:00:00+00:00    42.0
#                              ...
# 2018-12-31 18:00:00+00:00    85.0
# 2018-12-31 19:00:00+00:00    33.0
# 2018-12-31 20:00:00+00:00    31.0
# 2018-12-31 21:00:00+00:00    31.0
# 2018-12-31 22:00:00+00:00    31.0
# Name: generation solar, Length: 35064, dtype: float64

# %%
#Splitting data onto train and test
train_data, test_data = df_final[0:int(len(df_final)*0.9)], df_final[int(len(df_final)*0.9):]

# %%
train_data.shape
# Out:
# (31557, 105)

# %%
test_data.shape
# Out:
# (3507, 105)

# %%
train_arima = train_data[['generation solar','generation wind onshore']]
test_arima = test_data[['generation solar','generation wind onshore']]

# %%
train_arima
# Out:
#                            generation solar  generation wind onshore
# time
# 2014-12-31 23:00:00+00:00              49.0                   6378.0
# 2015-01-01 00:00:00+00:00              50.0                   5890.0
# 2015-01-01 01:00:00+00:00              50.0                   5461.0
# 2015-01-01 02:00:00+00:00              50.0                   5238.0
# 2015-01-01 03:00:00+00:00              42.0                   4935.0
# ...                                     ...                      ...
# 2018-08-07 15:00:00+00:00            4542.0                   3068.0
# 2018-08-07 16:00:00+00:00            3902.0                   3639.0
# 2018-08-07 17:00:00+00:00            3170.0                   4183.0
# 2018-08-07 18:00:00+00:00            2128.0                   4640.0
# 2018-08-07 19:00:00+00:00            1101.0                   4746.0
#
# [31557 rows x 2 columns]

# %%
# history = [x for x in train_arima]
# y = test_arima
# # make first prediction
# predictions = list()
# model = ARIMA(history, order=(1,1,0))
# model_fit = model.fit()
# yhat = model_fit.forecast()[0]
# predictions.append(yhat)
# history.append(y[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_n/r51n598j38q6fb1g7zhxmvt00000gn/T/ipykernel_94509/2824223575.py in <module>
#       3 # make first prediction
#       4 predictions = list()
# ----> 5 model = ARIMA(history, order=(1,1,0))
#       6 model_fit = model.fit()
#       7 yhat = model_fit.forecast()[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     151         # this criteria. Instead, we'll just make sure that the parameter
#     152         # estimates from those methods satisfy the criteria.)
# --> 153         self._spec_arima = SARIMAXSpecification(
#     154             endog, exog=exog, order=order, seasonal_order=seasonal_order,
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(solar); axes[0, 0].set_title('Original Series')
plot_acf(solar, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(solar.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(solar.diff(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(solar.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(solar.diff().diff(), ax=axes[2, 1])

plt.show()
# Out:
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_n/r51n598j38q6fb1g7zhxmvt00000gn/T/ipykernel_96462/2979646648.py in <module>
#      16 plot_acf(solar.diff().diff(), ax=axes[2, 1])
#      17
# ---> 18 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     387     """
#     388     _warn_if_gui_out_of_main_thread()
# --> 389     return _get_backend_mod().show(*args, **kwargs)
#     390
#     391
#
# ...

# %%
# 1,1,2 ARIMA Model
model = ARIMA(solar, order=(1,1,2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:       generation solar   No. Observations:                35064
# Model:                 ARIMA(1, 1, 2)   Log Likelihood             -247662.245
# Date:                Sun, 24 Mar 2024   AIC                         495332.490
# ...

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_n/r51n598j38q6fb1g7zhxmvt00000gn/T/ipykernel_96462/2753736558.py in <module>
# ----> 1 ax.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
model.plot_diagnostics(figsize=(10,8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_n/r51n598j38q6fb1g7zhxmvt00000gn/T/ipykernel_96462/4141690751.py in <module>
# ----> 1 model.ARIMAResults.plot_diagnostics(figsize=(10,8))
#       2 plt.show()
#
# AttributeError: 'ARIMA' object has no attribute 'ARIMAResults'

# %%
# Actual vs Fitted
fig, ax = plt.subplots()
ax = solar.plot(ax=ax)
plot_predict(model_fit, ax=ax, alpha=0.05, dynamic=False)
plt.show()

# %%
forecast = model_fit.forecast(steps=10)
print(forecast)
# Out:
# 2018-12-31 23:00:00+00:00    20.751260
# 2019-01-01 00:00:00+00:00    13.960606
# 2019-01-01 01:00:00+00:00    10.358199
# 2019-01-01 02:00:00+00:00     8.447141
# 2019-01-01 03:00:00+00:00     7.433335
# 2019-01-01 04:00:00+00:00     6.895516
# 2019-01-01 05:00:00+00:00     6.610205
# 2019-01-01 06:00:00+00:00     6.458850
# 2019-01-01 07:00:00+00:00     6.378556
# 2019-01-01 08:00:00+00:00     6.335961
# Freq: H, Name: predicted_mean, dtype: float64

# %%
plt.plot(solar, label='Original Data')

plt.plot(pd.date_range(start=solar, periods=10, freq='M'), forecast, label='Forecast', color='red')
plt.title('ARIMA Model Forecast')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_n/r51n598j38q6fb1g7zhxmvt00000gn/T/ipykernel_96462/1837451513.py in <module>
#       1 plt.plot(solar, label='Original Data')
#       2
# ----> 3 plt.plot(pd.date_range(start=solar, periods=10, freq='M'), forecast, label='Forecast', color='red')
#       4 plt.title('ARIMA Model Forecast')
#       5 plt.xlabel('Date')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, inclusive, **kwargs)
#    1085         freq = "D"
#    1086
# -> 1087     dtarr = DatetimeArray._generate_range(
#    1088         start=start,
#    1089         end=end,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive)
# ...

# %%
wind = df_final['generation wind onshore']

# %%
# # 1,1,2 ARIMA Model
# model_solar = ARIMA(wind, order=(1,1,2))
# model_fit_solar = model.fit()
# print(model_fit.summary())
# Out:
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# /Users/Daniyar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
#                                   SARIMAX Results
# ...
# Dep. Variable:     generation wind onshore   No. Observations:                35064
# Model:                      ARIMA(1, 1, 2)   Log Likelihood             -276686.872
# Date:                     Sun, 24 Mar 2024   AIC                         553381.744
# ...
